# %% [markdown]
# # Fixing `air_pollution_score` Data Type
# - 2008: convert string to float
# - 2018: convert int to float
#
# Load datasets `data_08_v3.csv` and `data_18_v3.csv`. You should've created these data files in the previous section: *Fixing Data Types Pt 1*.

# %%
# load datasets
import pandas as pd
df_08 = pd.read_csv('data_08_v3.csv')
df_18 = pd.read_csv('data_18_v3.csv')

# %%
# try using pandas' to_numeric or astype function to convert the
# 2008 air_pollution_score column to float -- this won't work
#df_08['air_pollution_score']

# %% [markdown]
# # Figuring out the issue
# Looks like this isn't going to be as simple as converting the datatype. According to the error above, the air pollution score value in one of the rows is "6/4" - let's check it out.

# %%
df_08[df_08.air_pollution_score == '6/4']
# Out:
#                   model  displ  cyl    trans drive         fuel  veh_class  \
# 582  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol/gas  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 582                 6/4    13/18   19/25   15/21                  7/6       no

# %% [markdown]
# # It's not just the air pollution score!
# The mpg columns and greenhouse gas scores also seem to have the same problem - maybe that's why these were all saved as strings! According to [this link](http://www.fueleconomy.gov/feg/findacarhelp.shtml#airPollutionScore), which I found from the PDF documentation:
#
#     "If a vehicle can operate on more than one type of fuel, an estimate is provided for each fuel type."
#
# Ohh... so all vehicles with more than one fuel type, or hybrids, like the one above (it uses ethanol AND gas) will have a string that holds two values - one for each. This is a little tricky, so I'm going to show you how to do it with the 2008 dataset, and then you'll try it with the 2018 dataset.

# %%
# First, let's get all the hybrids in 2008
hb_08 = df_08[df_08['fuel'].str.contains('/')]
hb_08
# Out:
#                   model  displ  cyl    trans drive         fuel  veh_class  \
# 582  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol/gas  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 582                 6/4    13/18   19/25   15/21                  7/6       no

# %% [markdown]
# Looks like this dataset only has one! The 2018 has MANY more - but don't worry - the steps I'm taking here will work for that as well!

# %%
# hybrids in 2018
hb_18 = df_18[df_18['fuel'].str.contains('/')]

# %% [markdown]
# We're going to take each hybrid row and split them into two new rows - one with values for the first fuel type (values before the "/"), and the other with values for the second fuel type (values after the "/"). Let's separate them with two dataframes!

# %%
# create two copies of the 2008 hybrids dataframe
df1 = hb_08.copy()  # data on first fuel type of each hybrid vehicle
df2 = hb_08.copy()  # data on second fuel type of each hybrid vehicle

# Each one should look like this
df1
# Out:
#                   model  displ  cyl    trans drive         fuel  veh_class  \
# 582  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol/gas  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 582                 6/4    13/18   19/25   15/21                  7/6       no

# %% [markdown]
# For this next part, we're going use pandas' apply function. See the docs [here](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.apply.html).

# %%
# columns to split by "/"
split_columns = ['fuel', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg', 'greenhouse_gas_score']

# apply split function to each column of each dataframe copy
for c in split_columns:
    df1[c] = df1[c].apply(lambda x: x.split("/")[0])
    df2[c] = df2[c].apply(lambda x: x.split("/")[1])

# %%
# this dataframe holds info for the FIRST fuel type of the hybrid
# aka the values before the "/"s
df1
# Out:
#                   model  displ  cyl    trans drive     fuel  veh_class  \
# 582  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 582                   6       13      19      15                    7       no

# %%
# this dataframe holds info for the SECOND fuel type of the hybrid
# aka the values after the "/"s
df2
# Out:
#                   model  displ  cyl    trans drive fuel  veh_class  \
# 582  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  gas  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 582                   4       18      25      21                    6       no

# %%
# combine dataframes to add to the original dataframe
new_rows = df1.append(df2)

# now we have separate rows for each fuel type of each vehicle!
new_rows
# Out:
#                   model  displ  cyl    trans drive     fuel  veh_class  \
# 582  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol  small car
# 582  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD      gas  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 582                   6       13      19      15                    7       no
# 582                   4       18      25      21                    6       no

# %%
# drop the original hybrid rows
df_08.drop(hb_08.index, inplace=True)

# add in our newly separated rows
df_08 = df_08.append(new_rows, ignore_index=True)

# %%
# check that all the original hybrid rows with "/"s are gone
df_08[df_08['fuel'].str.contains('/')]
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df_08.shape
# Out:
# (987, 13)

# %% [markdown]
# # Repeat this process for the 2018 dataset

# %%
# create two copies of the 2018 hybrids dataframe, hb_18
df1 = hb_18.copy()
df2 = hb_18.copy()

# %% [markdown]
# ### Split values for `fuel`, `city_mpg`, `hwy_mpg`, `cmb_mpg`
# You don't need to split for `air_pollution_score` or `greenhouse_gas_score` here because these columns are already ints in the 2018 dataset.

# %%
# list of columns to split
split_columns = ['fuel', 'city_mpg', 'hwy_mpg', 'cmb_mpg']

# apply split function to each column of each dataframe copy
for c in split_columns:
    df1[c] = df1[c].apply(lambda x: x.split("/")[0])
    df2[c] = df2[c].apply(lambda x: x.split("/")[1])

# %%
# append the two dataframes
new_rows = df1.append(df2)

# drop each hybrid row from the original 2018 dataframe
# do this by using pandas' drop function with hb_18's index
df_18.drop(hb_18.index, inplace=True)

# append new_rows to df_18
df_18 = df_18.append(new_rows, ignore_index=True)
df_18
# Out:
#                                  model  displ  cyl       trans drive  \
# 0                            ACURA RDX    3.5    6  SemiAuto-6   2WD
# 1                            ACURA RDX    3.5    6  SemiAuto-6   4WD
# 2                            ACURA TLX    2.4    4       AMS-8   2WD
# 3                            ACURA TLX    3.5    6  SemiAuto-9   2WD
# 4                            ACURA TLX    3.5    6  SemiAuto-9   4WD
# 5                 ACURA TLX AWD A-SPEC    3.5    6  SemiAuto-9   4WD
# 6                 ACURA TLX FWD A-SPEC    3.5    6  SemiAuto-9   2WD
# 7                        ALFA ROMEO 4C    1.8    4   AutoMan-6   2WD
# 8                    ALFA ROMEO Giulia    2.9    6      Auto-8   2WD
# 9                              AUDI A3    2.0    4       AMS-6   4WD
# 10                             AUDI A3    2.0    4       AMS-7   2WD
# 11                   AUDI A3 Cabriolet    2.0    4       AMS-6   4WD
# 12                   AUDI A3 Cabriolet    2.0    4       AMS-7   2WD
# 13                             AUDI A4    2.0    4       AMS-7   4WD
# 14                             AUDI A4    2.0    4       Man-6   4WD
# 15                       AUDI A4 Ultra    2.0    4       AMS-7   2WD
# 16                             AUDI A5    2.0    4       AMS-7   4WD
# 17                             AUDI A5    2.0    4       Man-6   4WD
# 18                   AUDI A5 Cabriolet    2.0    4       AMS-7   4WD
# 19           AUDI A5 Sportback quattro    2.0    4       AMS-7   4WD
# 20                             AUDI A6    2.0    4       AMS-7   2WD
# 21                             AUDI A6    2.0    4  SemiAuto-8   4WD
# 22                             AUDI A6    3.0    6  SemiAuto-8   4WD
# 23                             AUDI A7    3.0    6  SemiAuto-8   4WD
# 24                           AUDI A8 L    3.0    6  SemiAuto-8   4WD
# 25                             AUDI Q3    2.0    4  SemiAuto-6   2WD
# 26                             AUDI Q3    2.0    4  SemiAuto-6   4WD
# 27                             AUDI Q5    2.0    4  SemiAuto-7   4WD
# 28                             AUDI Q7    2.0    4  SemiAuto-8   4WD
# 29                             AUDI Q7    3.0    6  SemiAuto-8   4WD
# ..                                 ...    ...  ...         ...   ...
# 802            CHEVROLET Suburban 1500    5.3    8      Auto-6   2WD
# 803            CHEVROLET Suburban 1500    5.3    8      Auto-6   4WD
# 804               CHEVROLET Tahoe 1500    5.3    8      Auto-6   2WD
# 805               CHEVROLET Tahoe 1500    5.3    8      Auto-6   4WD
# 806                     CHEVROLET Volt    1.5    4         CVT   2WD
# 807                     CHEVROLET Volt    1.5    4         CVT   2WD
# 808                       CHRYSLER 300    3.6    6      Auto-8   2WD
# 809                       CHRYSLER 300    3.6    6      Auto-8   4WD
# 810                      DODGE Charger    3.6    6      Auto-8   2WD
# 811                      DODGE Charger    3.6    6      Auto-8   4WD
# 812  FORD Fusion Energi Plug-in Hybrid    2.0    4         CVT   2WD
# 813                      GMC Sierra 15    4.3    6      Auto-6   2WD
# 814                      GMC Sierra 15    4.3    6      Auto-6   4WD
# 815                      GMC Sierra 15    5.3    8      Auto-6   2WD
# 816                     GMC Yukon 1500    5.3    8      Auto-6   2WD
# 817                     GMC Yukon 1500    5.3    8      Auto-6   4WD
# 818                  GMC Yukon 1500 XL    5.3    8      Auto-6   2WD
# 819                  GMC Yukon XL 1500    5.3    8      Auto-6   4WD
# 820                      JEEP Cherokee    2.4    4      Auto-9   2WD
# 821                      JEEP Cherokee    2.4    4      Auto-9   4WD
# 822                       KARMA Revero    2.0    4      Auto-1   2WD
# 823        MERCEDES-BENZ CLA250 4Matic    2.0    4   AutoMan-7   4WD
# 824        MERCEDES-BENZ GLA250 4Matic    2.0    4   AutoMan-7   4WD
# 825        MERCEDES-BENZ GLE350 4Matic    3.5    6      Auto-7   4WD
# 826     MINI Cooper SE Countryman All4    1.5    3  SemiAuto-6   4WD
# 827                 TOYOTA Sequoia FFV    5.7    8  SemiAuto-6   4WD
# 828                  TOYOTA Tundra FFV    5.7    8  SemiAuto-6   4WD
# 829                          VOLVO S90    2.0    4  SemiAuto-8   4WD
# 830                        VOLVO XC 60    2.0    4  SemiAuto-8   4WD
# 831                        VOLVO XC 90    2.0    4  SemiAuto-8   4WD
#
#             fuel     veh_class  air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 0       Gasoline     small SUV                    3       20      28      23
# 1       Gasoline     small SUV                    3       19      27      22
# 2       Gasoline     small car                    3       23      33      27
# 3       Gasoline     small car                    3       20      32      24
# 4       Gasoline     small car                    3       21      30      24
# 5       Gasoline     small car                    3       20      29      23
# 6       Gasoline     small car                    3       20      30      23
# 7       Gasoline     small car                    1       24      34      28
# 8       Gasoline   midsize car                    3       17      24      20
# 9       Gasoline     small car                    7       24      31      27
# 10      Gasoline     small car                    7       26      35      29
# 11      Gasoline     small car                    7       22      30      25
# 12      Gasoline     small car                    7       25      33      28
# 13      Gasoline     small car                    5       24      34      27
# 14      Gasoline     small car                    3       24      33      27
# 15      Gasoline     small car                    3       27      37      31
# 16      Gasoline     small car                    5       24      34      27
# 17      Gasoline     small car                    3       24      33      27
# 18      Gasoline     small car                    5       24      34      27
# 19      Gasoline   midsize car                    5       24      34      27
# 20      Gasoline   midsize car                    5       25      34      28
# 21      Gasoline   midsize car                    5       22      31      26
# 22      Gasoline   midsize car                    3       20      29      23
# 23      Gasoline   midsize car                    3       20      29      23
# 24      Gasoline     large car                    3       19      29      22
# 25      Gasoline     small car                    3       20      28      23
# 26      Gasoline     small car                    3       20      28      23
# 27      Gasoline     small SUV                    3       23      27      25
# 28      Gasoline  standard SUV                    3       19      25      21
# 29      Gasoline  standard SUV                    3       19      25      21
# ..           ...           ...                  ...      ...     ...     ...
# 802          Gas  standard SUV                    3       16      23      19
# 803          Gas  standard SUV                    3       16      22      18
# 804          Gas  standard SUV                    3       16      23      19
# 805          Gas  standard SUV                    3       16      22      18
# 806  Electricity     small car                    3      113      99     106
# 807  Electricity     small car                    7      113      99     106
# 808          Gas     large car                    3       19      30      23
# 809          Gas     large car                    3       18      27      21
# 810          Gas     large car                    3       19      30      23
# 811          Gas     large car                    3       18      27      21
# 812  Electricity   midsize car                    7      102      91      97
# 813          Gas        pickup                    5       18      24      20
# 814          Gas        pickup                    5       17      22      19
# 815          Gas        pickup                    3       16      23      19
# 816          Gas  standard SUV                    3       16      23      19
# 817          Gas  standard SUV                    3       16      22      18
# 818          Gas  standard SUV                    3       16      23      19
# 819          Gas  standard SUV                    3       16      22      18
# 820          Gas     small SUV                    3       21      30      25
# 821          Gas     small SUV                    3       21      28      23
# 822  Electricity     small car                    1       59      61      60
# 823          Gas     small car                    5       24      32      27
# 824          Gas     small SUV                    5       23      31      26
# 825          Gas  standard SUV                    3       18      22      19
# 826  Electricity   midsize car                    3       63      66      65
# 827          Gas  standard SUV                    5       13      17      14
# 828          Gas        pickup                    5       13      17      15
# 829  Electricity   midsize car                    7       70      72      71
# 830  Electricity     small SUV                    7       60      58      59
# 831  Electricity  standard SUV                    7       63      61      62
#
#      greenhouse_gas_score smartway
# 0                       5       No
# 1                       4       No
# 2                       6       No
# 3                       5       No
# 4                       5       No
# 5                       5       No
# 6                       5       No
# 7                       6       No
# 8                       4       No
# 9                       6       No
# 10                      6       No
# 11                      5       No
# 12                      6       No
# 13                      6       No
# 14                      6       No
# 15                      7      Yes
# 16                      6       No
# 17                      6       No
# 18                      6       No
# 19                      6       No
# 20                      6       No
# 21                      5       No
# 22                      5       No
# 23                      5       No
# 24                      4       No
# 25                      5       No
# 26                      5       No
# 27                      5       No
# 28                      4       No
# 29                      4       No
# ..                    ...      ...
# 802                     3       No
# 803                     3       No
# 804                     3       No
# 805                     3       No
# 806                    10      Yes
# 807                    10    Elite
# 808                     5       No
# 809                     4       No
# 810                     5       No
# 811                     4       No
# 812                    10    Elite
# 813                     4       No
# 814                     3       No
# 815                     3       No
# 816                     3       No
# 817                     3       No
# 818                     3       No
# 819                     3       No
# 820                     5       No
# 821                     5       No
# 822                    10       No
# 823                     6       No
# 824                     5       No
# 825                     3       No
# 826                     9      Yes
# 827                     1       No
# 828                     2       No
# 829                    10    Elite
# 830                    10    Elite
# 831                    10    Elite
#
# [832 rows x 13 columns]

# %%
# check that they're gone
df_18[df_18['fuel'].str.contains('/')]
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df_18.shape
# Out:
# (832, 13)

# %% [markdown]
# ### Now we can comfortably continue the changes needed for `air_pollution_score`! Here they are again:
# - 2008: convert string to float
# - 2018: convert int to float

# %%
# convert string to float for 2008 air pollution column
df_08['air_pollution_score'] = df_08['air_pollution_score'].astype(float)

# %%
# convert int to float for 2018 air pollution column
df_18['air_pollution_score'] = df_18['air_pollution_score'].

# %%
df_08.to_csv('data_08_v4.csv', index=False)
df_18.to_csv('data_18_v4.csv', index=False)
